# %% [markdown]
# # 🌿 GeoGreen Revolution — Presentation Notebook
#
# Use this notebook to set up and run the project directly from VS Code.
#
# ### Step 1: Install Dependencies

# %%
# %pip install -r requirements.txt
# %pip install streamlit easyocr
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Step 2: Download Data (Only if needed)
# If you don't have data in the `data/` folder, run the cell below to generate sample data.

# %%
import os
if not os.path.exists('data/satellite/sehore_sentinel2.tif'):
    print("Generating dummy data...")
    # !python generate_dummy_data.py
else:
    print("✅ Data found!")
# Out:
# ✅ Data found!

# %% [markdown]
# ### Step 3: Run the Dashboard
# Running the cell below will start the **Streamlit Dashboard**.
# It will provide a **Local URL** (e.g., `http://localhost:8501`) in the output.
# **Click that URL** to open the dashboard in your browser.
#
# > **Note:** This cell will keep running while the dashboard is active. To stop it, click the **Stop** button in VS Code.

# %%
# !streamlit run app.py

# %% [markdown]
# ### Alternative: Run Backend Pipeline
# If you prefer to see the backend processing logs:

# %%
# !python src/main.py
